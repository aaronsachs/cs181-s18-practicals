# %%
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
feats = range(20, 150, 10)
scores = [
    0.8826, 
    0.8671, 
    0.8756, 
    0.8710, 
    0.8756, 
    0.8775, 
    0.8775, 
    0.8769, 
    0.8769, 
    0.8736, 
    0.8743, 
    0.8775, 
    0.8808
]

# %%
plt.plot(feats, scores)

# %%
# fig, ax = plt.subplots(1, 1, figsize = (10, 8))

# NB tri, RF tri + f/l, NN tri + f/l, GB tri + f/l, RF bi + f/l, 
# NN bi + f/l, GB bi + f/l, RF quad + f/l, NN quad + f/l
plt.figure(figsize = (12, 8))
scores = [0.7362, 0.8808, 0.8756, 0.8801, 0.8934, 0.8684, 0.8769, 0.8671, 0.8814]
colors = ['pink', 'red', 'orange', 'purple', 'red', 'orange', 'purple', 'red', 'orange']
names = [
    'NB Trigrams', 
    'RF Trigram \n+ Indicator', 
    'NN Trigram \n+ Indicator',
    'GB Trigram \n+ Indicator',
    'RF Bigram \n+ Indicator', 
    'NN Bigram \n+ Indicator', 
    'GB Bigram \n+ Indicator',
    'RF Quadgram \n+ Indicator', 
    'NN Quadgram \n+ Indicator'
]
plt.bar(range(9), scores, color = colors)
plt.xticks(range(9), names)
plt.title("Test Accuracy of NB, RF, NN, GB\n Under Different Features\n(NB = Naive Bayes, RF = Random Forest, NN = Neural Net, GB = Gradient Boosting)")
